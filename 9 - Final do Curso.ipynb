# %% [markdown]
# **Introdução a Programação + Python + Hands On**
# > **Autor: Sthefanie Passo**

# %% [markdown]
# ##**Final do Curso**

# %% [markdown]
# * 1. Conceitos Básicos de Programação
# * 2. Variáveis, Tipos de Variáveis
# * 3. Entradas, Saídas e Impressão
# * 4. Operadores: Matemáticos, Relacionais e Lógicos
# * 5. Estruturas de Controle
# * 6. Estruturas de Repetição
# * 7. Estruturas de Dados Homogênea
# * 8. Estruturas de Dados Heterogênea **(BONUS)**

# %% [markdown]
# ![alt text](https://hackernoon.com/hn-images/1*QPSlOyQ0EeJG169-JBYOUQ.gif)
