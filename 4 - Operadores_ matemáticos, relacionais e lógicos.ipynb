# %% [markdown]
# **Introdução a Programação + Python + Hands On**
#
# > **Autora: Sthefanie Passo**

# %% [markdown]
# #**Operadores**

# %% [markdown]
# #**Operadores matemáticos**
#
# O Python pode ser utilizado como uma calculadora matemática avançada. Praticamente, todos os operadores aritméticos funcionam da mesma forma como os conhecemos da matemática elementar.
#
#
#     Operação	    Operador
#     adição	          +
#     subtração	       -
#     multiplicação	   *
#     divisão         	/
#     --------------------------
#     exponenciação	   **
#     parte inteira	   //
#     módulo	          %
#
# **Exemplos:**

# %% [markdown]
# *Soma/ Concatenação*

# %%
print(10+10,'ca'+'sa')
# Out:
# 20 casa

# %% [markdown]
#  *Subtração*

# %%
calculo = 10+20
print(calculo)
# Out:
# 30

# %% [markdown]
# *Multiplicação*

# %%
x = 30
y=5
calculo = x*y
print(calculo)
# Out:
# 150

# %% [markdown]
# *Divisão*

# %%
x = 30
y=5
calculo = x/y
print(calculo)
# Out:
# 6.0

# %% [markdown]
# *Exponenciação*

# %%
x = 30
y=5
calculo = x**y #Math.pow(x,y)
print(calculo)
# Out:
# 24300000

# %% [markdown]
# Parte Inteira

# %%
x = 32
y=5
calculo = x//y #Math.pow(x,y)
print(calculo)
# Out:
# 6

# %% [markdown]
# *Módulo/ Resto da divisão*

# %%
x = 32
y=5
calculo = x%y #Math.pow(x,y)
print(calculo)
# Out:
# 2

# %% [markdown]
# **Expressões matemáticas**
#
# As operações separadas por parenteses são executadas da mais interna para a mais externa, sempre realizando a operação e atribuindo o seu resultado a próxima expressão.
#
#     2 * (3 + ((2 * 5) + (3 -1)))
#
# Caso a expressão não seja separada por parenteses, a ordem de execução das operações segue a regra de precedência matemática:
#
# 1. Potenciação
# 2. Multiplicação e divisão
# 3. Adição e subtração
#
# **Exemplos**

# %%
print(2 * 3 + 2 * 5 + 3 - 1)
# Out:
# 18

# %%
print(2 * 3 + 2 * (5 + 3 - 1)**2)
# Out:
# 104

# %% [markdown]
# #**Operadores Relacionais**
#
# Operador Relacional é todo operador que obtém a relação do membro a esquerda com o membro a sua direita.
#
#
#
# ```
# Descrição	       Operador
# Maior que	          >
# Menor que	          <             - Simples
# Igual a	            ==
# --------------------------------
# Maior ou igual a	   >=
# Menor ou igual a	   <=
# ```
# Para obtermos a relação entre 2 membros, temos que utilizar a seguinte estrutura:
# ```
# <membro a esquerda> OPERADOR <membro a direita>
# ```
#
# **Exemplos:**

# %% [markdown]
# *Igualdade*

# %%
num = 8 #atribuição
calculo = (-9+8+9)
print(num==calculo) #comparação
# Out:
# True

# %% [markdown]
# *Diferença*

# %%
num = 8 #atribuição
print(num!=8) #comparação
# Out:
# False

# %% [markdown]
# *Maior que (maior ou igual que)*

# %%
num = 8 #atribuição
print(9<=num) #comparação
# Out:
# False

# %% [markdown]
#  *Menor que (menor ou igual que)*

# %%
num = int (1.999999) #atribuição
num1 = 1.999999
print(num, num1, num<num1) #comparação
# Out:
# 1 1.999999 True

# %% [markdown]
# **Outros exemplos**
#
#     2 == 2.0 (...)
#     1.9999999 != 1.9 (...)
#     "a" > "b" (...)
#     1 <= "1" (...)

# %% [markdown]
# #**Operadores Lógicos**
# O valor lógico é um tipo de dado binário, isto é, assume um valor dentre duas opções: verdadeiro ou falso.
#
# Os valores lógicos são de fato a base de toda a computação, até porque, temos que, o bit está ligado ou o bit está desligado.
# O valor lógico em sua forma mais primitiva assume o número 1 quando **verdadeiro** e assume o valor 0 quando **falso** do tipo booleano.

# %% [markdown]
# **Conectivos Lógicos**
# Os dois conectivos lógicos são:
# ```
# Conectivo de conjunção: E
# Conectivo de disjunção: OU
# ```
# Os conectivos lógicos devem ser entendidos como ferramenta de notação utilizada para unir duas ou mais expressões, e como resultado da união, forma-se uma nova expressão.

# %%
True and False
# Out:
# False

# %% [markdown]
# O conectivo lógico de conjunção **E**, une a expressão a sua esquerda a expressão a sua direita: A é verdadeiro e B é verdadeiro.

# %%
a = False
b = True
print(a and b)
# Out:
# False

# %% [markdown]
# O conectivo lógico de disjunção **OU** liga a expressão a sua esquerda a expressão a sua direita: A é verdadeiro OU B é verdadeiro.

# %%
a = False
b = False
print(a or b)
# Out:
# False

# %% [markdown]
# O conectivo lógico de disjunção exclusiva **NÃO** nega a a expressão a sua direita: NÃO A.

# %%
a = True 
negado = !=a
print(negado)
# Out:
# ['/bin/bash: =a: command not found']

# %% [markdown]
# **Resumo dos Operadores Lógicos:**
#
# ![alt text](data:image/png;base64,...)

# %% [markdown]
# EXPRESSÕES SIMPLES E COMPOSTAS
#
# Os operadores relacionais obtém a relação entre os operandos e, por isso, podemos chamar esse tipo de expressão como sendo, **expressões simples**.
#
# As **expressões composta**s, por sua vez, são a união de 2 ou mais expressões simples e, ligadas por algum conectivo lógico.
#
# ```
# EXEMPLO 1
# isso E isso
#
# EXEMPLO 2
# x E y
# ```

# %%
# expressão simples: "a" != "B"
# expressão simples: "B" == "b"
# expressão composta: "a" != "B" or "B" == "b"
print( "a" != "B" or "B" == "b")
# Out:
# True

# %% [markdown]
# Referências:
#
# [Operadores](https://pt.slideshare.net/wbezerra/log-06-operadores)
#
# [Operadores Matemáticos em Python](http://excript.com/python/operador-aritmetico-em-python.html)
#
# [Operadores Lógicos em Python](http://excript.com/python/operadores-logicos-python.html)
#
# [Operadores Relacionais](http://excript.com/python/operador-relacional-python.html)
