# %% [markdown]
# **Introdução a Programação + Python + Hands On**
# > **Autora: Sthefanie Passo**

# %% [markdown]
# # **Variáveis, Tipo de Variáveis**
#
# # Algoritmo
# Um algoritmo é uma sequência **finita** e não ambígua de instruções computáveis para **solucionar um problema**. Um algoritmo consiste em uma expressão textual das etapas da resolução de algum problema, seja ele computacional ou não. Um exemplo clássico de algoritmo não-computacional é uma **receita de bolo**.
#
# # Variável
# Uma variável é um espaço na **memória** do computador destinado a um **dado que é alterado durante a execução** do algoritmo. Para funcionar corretamente, as variáveis precisam ser **definidas** por nomes e tipos.

# %% [markdown]
# ```
# Algoritmo "Teste de Variável"
# Declaração das variáveis
#    nome : Texto
# Inicio
#    nome <- “João”
#    imprimir(nome)
#    nome <- “Maria”
#    imprimir(nome)
# Fim
# --------------------------------------------------------------------
# Memória   |   Tipo Var   |   Nome   |   Conteúdo   |   Interação
#   123     |    Texto     |   nome   |    João      |      1
#                Texto     |   nome   |    Maria     |      2
#   124     |              |          |              |
#   125     |              |          |              |
#   126     |              |          |              |
# ```

# %% [markdown]
# Logo os tipos de dados primitivos são:
#
# ```
#                                        Tipos de Dados Primitivos
#                        _________________________|_________________________
#                        |                        |                         |
#                   Numérico                   Literal                    Lógico
#                 _______|______
#               |               |
#           Inteiro            Real
#
#
# ```
#
#
# Como o objetivo desta aula é apresentar somente os dados mais importantes para introdução a programação, vamos estudar mais a fundo somente o tipo **Numérico** e **Literal**

# %% [markdown]
# # **Tipo de Variáveis**
#
# ## **Numéricas**
# **INTEIRO**: Os números inteiros são aqueles que não possuem componentes decimais ou fracionários, podendo ser positivos ou negativos. (Conj. dos N e Z)
# Ex.:    -2     0     2 (int)
#
#
# **REAL**: Os dados de tipo real são **aqueles** que podem possuir componentes decimais ou fracionários, e podem também ser positivos ou negativos.
# Ex.:     24.01   144.    -13.33     0.0     0. (float, double)
#
# ![alt text](https://pt-static.z-dn.net/files/d11/7bb1147beb4ee186f7d55e2612ca6a76.jpg)
#
#
# ## **Literais**
# O tipo de dado **LITERAL** é constituído por uma seqüência de caracteres contendo letras, dígitos e/ou símbolos especiais.
# Este tipo de dados é também muitas vezes chamado de alfanumérico, cadeia (ou cordão) de caracteres, ainda, do inglês, STRING.
# Usualmente, os dados literais são representados nos algoritmos pela coleção de caracteres, delimitada em seu início e término com o caractere aspas (").
# Diz-se que o dado do tipo literal possui um comprimento dado pelo número de caracteres nele contido
#
# ```
# Exemplo:
# "QUAL ?”     - literal de comprimento 6
# ‘ ‘          - literal de comprimento 1
# "qUaL ?!$"   - literal de comprimento 8
# " AbCdefGHi" - literal de comprimento 9
# "1-2+3="     - literal de comprimento 6
# ‘0’          - literal de comprimento 1
# ```
#
# ## **Lógicos**
# Este tipo de dados pode assumir apenas dois valores **VERDADEIRO ou FALSO**. Também é conhecido como booleano. Reserva apenas um bit na memória, onde o valor 1 representa VERDADEIRO e o valor 0 representa FALSO. Por exemplo uma variável status_da_lâmpada (acesa ou apagada).
# Exemplo:  V (valor lógico verdadeiro)
# 	       F (Valor lógico falso)
#
# ![alt text](https://png.clipart.me/previews/731/lightbulb-on-off-clip-art-45229.jpg)
#
# # **Revisando**
# ```
# NOME : literal
# IDADE : inteiro
# SALARIO: real
# TEM_FILHOS: lógico
# Por isso devemos especificar em nossos algoritmos o tipo de cada variável
# Curiosidade: em python não é preciso declara os tipos primitivos das variáveis
# ```
# ![alt text](https://lh3.googleusercontent.com/proxy/s75E7TRcQGagomKPO1Y1zkfjN2Lb7YmOrEK45gp3jz9qmCYWVKljw_3THzeDHU25CS8kMom8FLNevtvr_qZLZzcpb7JHROFHCwfkF8oV16K6qlWhbWPsjBoy6wLCkSf2-w)
#
# A partir dos tipos de dados primitivos podemos criar outros tipos de dados utilizando uma combinação de variáveis. Estes outros tipos de dados são os **Tipos de dados customizados** como estruturas de dados, classes, vetores, matrizes, etc. Esses tipos de dados são criados pelo programador.
# Cena para os próximos capítulos...

# %%
while(2):
    print("Oi");
    #condição de parada
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# Oi
# ...

# %% [markdown]
# # Conversão de dados ou Coerção de Tipos

# %% [markdown]
# Linguagem tipada é aquela que permite a classificação das informações pelo uso de tipos de dados, por exemplo, o **Python** trata um conjunto de caracteres como sendo do tipo String, logo, o Python é uma linguagem tipada, no caso, uma **linguagem dinamicamente tipada**.

# %% [markdown]
# [Tipos de Dados em Python](http://excript.com/python/tipos-de-dados-python.html)

# %%
num = input()
coercao = int(num)
type(coercao)
# Out:
# 8
# int

# %% [markdown]
# Refazer o pseudocodigo "Teste de Variavel" dado no exemplo em Python

# %%
nome = input("Digite o seu nome: ")
print(nome)
nome = input("Digite o seu nome: ")
print(nome)
# Out:
# Digite o seu nome: Sthefanie
# Sthefanie
# Digite o seu nome: Jóshua
# Jóshua

# %% [markdown]
# Um aluno de computação resolveu contar quantas horas no mês ele passa estudando programação, ajude-o calcular essas horas de acordo com a quantidade de: dias que vai a faculdade, horas que permanece estudando e semanas que se tem naquele mês.

# %%
horas = int(input("Digite as horas de estudo: "))
dias = int(input("Digite os dias de estudo: "))
semanas = int(input("Digite as semanas: "))
total = horas*dias*semanas
print(total)
# Out:
# Digite as horas de estudo: 4
# Digite os dias de estudo: 5
# Digite as semanas: 4
# 80

# %% [markdown]
# Faça a media dos exercícios escolares com 3 avaliações

# %% [markdown]
# # **Memory Stuff** (Coisas de Memória)
# Durante a execução de um algoritmo computadore estão manipulando informações em **variáveis**. Para que não se **esqueça** das informações,o computador precisa guarda-las em sua memória volátil.
#
# ![alt text](https://slideplayer.com.br/slide/365635/3/images/1/Esquema+b%C3%A1sico+do+hardware.jpg)
#
# Logo o computador recebe entradas, processa de acordo com o algoritmo e envia uma saída para as unidades de saída:
#
# Este processamento é feito pela memória. A memória guarda os atributos das variáveis como: nome, tipo de dado associado à mesma e a informação por ela guardada.
#
# ![alt text](https://w1.ezcdn.com.br/artefatosdemadeirasuely/fotos/grande/13827fg1/organizador-12-gavetas-liso-40x12x30cm.jpg)
#
# Para que o armazenamento seja feito de forma correta deve-se declarar a variavel adequadamente:
#
# > O nome da variavel **deve** começar com uma **letra**
#
# > O nome da variavel **não** deve conter **símbolos especiais** exceto a undeline "_"
#
# ```
# ICOMP     = true
# 1COMP     = false (inicia com número)
# _numero   = true
# ICOMP1    = true
# tRuFt     = true
# data/hora = false (contém o caractere "/")
# a mora    = false (contém o caractere " ")
# ```
#
# Definição	de	variáveis	em	pseudocódigos
#
# > Todas	 as	 variáveis	 em	 algoritmos	 devem	 ser	 definidas	 antes	 de	serem	utilizadas.
#
# > Isto	 se	 faz	 necessário	 para	 permir	 que	 o	 compilador	 reserve	 um	espaço	 na	memória	para	as	mesmas.
#
# Sintaxe:
# • <nome_da_variável>	:	<tipo_da_variável>
# • <lista_de_variáveis>	:	<tipo_das_variáveis>
#
# # Revisão
# A	 memória	 dos	 computadores	 é	 composta	 por	 células	 numeradas
# ordenadamente	denominadas	bytes.	Cada	byte	é	constituído	por	8	bits.
#
# > Cada	tipo	de	dado	requer	um	número	diferente	de	bytes	para	armazenar	a	informação	representada	por	ele	na	memória.	Esta	quantidade	também	pode variar	em	função	do	tipo	de	computador	considerado.
#
# > Uma	 variável	 é	 uma	 entidade	 dotada	 de	 um	 nome	 para	 diferenciá-la	 das	demais	e	um	tipo	de	dado	que	define	o	tipo	de	informação	que	ela	é	capaz	de	guardar.	Uma	vez	definidos,	o	nome	e	o	tipo	de	uma	variável	não	podem	ser	alterados	no	decorrer	de	um	programa.	Por	outro	lado,	a	informação	útil	da	variável	é	objeto	de	constante	modificação	durante	o	decorrer	do	programa,	de	acordo	com	o	fluxo	de	execução	do	mesmo.

# %% [markdown]
# # **Exercícios de Fixação**

# %% [markdown]
# > 1.	Classifique	os	dados	especificados	abaixo	de	acordo	com	seu	tipo,	assinalando	com	I	os	dados	do	Gpo	inteiro,	com	R	os	reais,	com	L	os	literais,	com	B	os	lógicos	(booleanos),	e	com	N	aqueles	para	os	quais	não	é	possível	definir	a	priori	um	Gpo	de	dado.
# ```
# (		)	0.21    (		)	1
# (		)	V       (		)	“0.”
# (		)	1%      (		)	“José”
# (		)	0,35    (		)	.F.
# (	    )	-0.001  (	    )	.T.
# (		)	+3257   (		)	“a”
# (		)	“+3257” (		)	+3257.
# (		)	“-0.0”  (		)	“.F.”
# (		)	±	3  (		)	.V.
# (		)	.V      (		)	“abc”
# (		)	F       (		)	C
# (		)	Maria
# ```

# %% [markdown]
# > 2. Explique	o	que	está	errado	nos	identificadores	incorretos.
# ```
# (     )	valor    (		)	_b248    (		)	nota*do*aluno
# (     )	a1b2c3   (		)	3x4      (		)	Maria
# (     )	km/h     (		)	xyz      (		)	nome	empresa
# (     )	sala_215 (		)	“nota”   (		)	ah!
# Identificador: Explicação
# ```

# %% [markdown]
# > 3. Supondo	que	as	variáveis	NB,	NA,	NMAT	e	SX	sejam	utilizadas	para	armazenar	a	nota	do	aluno,	o	nome	do	aluno,	o	número	da	matrícula	e	o	sexo,	declare-as	corretamente,	associando	o	tipo	adequado	ao	dado	que	será	armazenado em pseudocódigo.
# ```
# Pseudocódigo ex. 3:
# ```

# %% [markdown]
# > 4. Escreva a declaração de uma variável do tipo caractere de nome rua em pseudocódigo
# ```
# Pseudocódigo ex. 4:
# ```
#
# > 5. Escreva a instrução de atribuição que atribui o nome de sua rua à variável do problema em pseudocódigo
# ```
# Pseudocódigo ex. 5:
# ```
#
# > 6. Escreva a declaração de uma variável do tipo logico de nome achou em pseudocódigo
# ```
# Pseudocódigo ex. 6:
# ```
#
# > 7. Escreva a instrução de atribuição que atribui a palavra reservada verdadeiro à variável do problema 6 em pseudocódigo
# ```
# Pseudocódigo ex. 7:
# ```

# %% [markdown]
# > 8. Faça um algoritmo em python que receba todas as variaveis dos exercício 4 a 7 e mostre os tipos dessas variaveis.

# %% [markdown]
# > 9. Escreva um algoritmo que leia um número inteiro x do usuário e calcule y, sendo que y é calculado pela fórmula y = x * x

# %% [markdown]
# > 10. Escreva um algoritmo que leia um número inteiro digitado pelo usuário e informe ao usuário o tipo de variavel utilizada.

# %% [markdown]
# > 11. Escreva um algoritmo que leia o nome de um aluno e as notas das três prova que ele obteve no semestre. No final informe o nome do aluno e a sua média (aritmética).

# %% [markdown]
# > 12. Identifique o tipo de dados dos seguintes valores:
# ```
# (a) "9 de agosto de 1968"
# (b) 1.3
# (c) falso
# (d) −31
# (e) "?"
# ```

# %% [markdown]
# Referencias:
#
# [Variaveis e Tipos de Dados - IFSP](https://pt.slideshare.net/andreconstantino/aula-8-lgica-de-programao-variveis-tipos-de-dados-e-operadores)
#
# [Variaveis, constantes e tipo de dados](https://mclp.dicasdeprogramacao.com.br/licao-3-variaveis-constantes-e-tipos-de-dados/)
#
# [Variáveis e Tipo de Dados - IFRN](https://docente.ifrn.edu.br/alessandrosouza/disciplinas/algoritmo/downloads/aula-3-variaveis-e-tipo-de-dados)
#
# [Tipos de Dados em Python](http://excript.com/python/tipos-de-dados-python.html)
#
# [Tipos de Dados e Variáveis - UFRN](https://www.dimap.ufrn.br/~richard/pubs/dim0320/readings/aula03.pdf)
